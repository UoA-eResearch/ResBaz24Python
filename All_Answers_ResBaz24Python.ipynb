# %% [markdown]
# # Bare minimum to get started
#
# ## Variables and data types

# %%
# this is a comment (this is more powerful that you think)
# We can use Python to do simple math
1+1

# %%
# We can also use Python to do more complex math
# Here we are calculating the square root of 2
import math
math.sqrt(2)

# %% [markdown]
# ### more detailed explanation:
# We just imported a package/library/an external component/something that someone else has built. One repository of such packages is the Python Package Index (PyPI) [pypi.org](https://pypi.org/).

# %%
# Let's not just have a number as an output, but let's add some text describing it
print("The square root of 2 is:", math.sqrt(2))

# %%
# Let's only show the first 3 decimal points
print("The square root of 2 is:", round(math.sqrt(2),3))

# %% [markdown]
# # Variables and data types
#
# - Python is dynamically typed (aka duck-typed 🦆)
# - We don't have to specify what kind of data we want to store in a variable
# - Python will figure it out for us

# %%
square_root_of_two = round(math.sqrt(2),3) # we store the value in a variable, we use lowercase for variable names

# %% [markdown]
# as you can see, there is nothing to see

# %%
print(square_root_of_two)

# %%
# let's use a really neat trick to print the value of a variable
print(f"The square root of 2 is: {square_root_of_two}")
# this is refered to as an f-string

# %%
# and we can make even shorten this further; remember if we take this to an extreme, it is considered Code Golf (https://en.wikipedia.org/wiki/Code_golf) 🏌️
# let's create a new variable that holds the non-rounded result
full_square_root_of_two = math.sqrt(2)
print(f"The square root of 2 is: {full_square_root_of_two:.2f}") #so by adding :.2f we are rounding to 2 decimal points

# %% [markdown]
# This does not only work for numbers or maths, etc. but also for text:

# %%
name = "my name is John Doe" # we 'escape' the string by putting quotation marks around it; we prefer double quotes over single ones
# on a side-note in a Jupyter Notebook we often don't need to use the print function
name

# %%
age = 42
age
# Out:
# 42

# %%
# Let's see what happens when we try to add a string and a number
# name_and_age = name + age

# %% [markdown]
# On a side-note: Python errors tend to be 'verbose', they might seem intimidating. Read them bottom to top. Use online resources to get help. There is a big community!

# %%
# Make Python show us the type of the variable
type(name)

# %% [markdown]
# and another example of data types and consequences

# %%
# Let's try to find out how many decimal points some number has
# let's use the number Pi (because it is infinite)
Pi = math.pi
Pi

# we could think that we can just put a len() around it, but that doesn't work

# Convert the float to a string
pi_str = str(Pi)

# Get the length of the string
pi_length = len(pi_str)
pi_length

# %%
type(Pi)

# %% [markdown]
# # More complex data types

# %%
# Lets have a list of names
names = ["John", "Jane", "Jack", "Jill"]
names

# %%
# Let's only show the first element of the list
names[1]

# %% [markdown]
# Wait! Jane? 🤔
# Yes, Python is zero-indexed! 🤯
# If we want to see the first element of a list, we need to use `list[0]` 🤯

# %%
names[0]

# %%
veg = [
    ["lettuce", "lettuce", "peppers", "zucchini"],
    ["lettuce", "lettuce", "peppers", "zucchini"],
    ["lettuce", "cilantro", "peppers", "zucchini"]
]

print(veg)

# %%
# or more neatly formatted
import pprint

# Pretty print the list of lists
pprint.pprint(veg)

# %% [markdown]
# let's try to find the cilantro 🌿

# %%
print(veg[2][1])

# %%
# Demonstration: How to get a subset of a list
names[0:2]

# %%
# Demonstration: How to append a list
names.append("James")
names
# so we can have duplicates!

# %% [markdown]
# # "Quick shots"

# %%
# Example 1 if-statement: To check if a number is positive
number = 10  # You can change this number to test different cases

if number > 0: # pay close attention to the Syntax Highlighting, if is a reserved keyword, the colon matters, so does the indentation!
    print("The number is positive!")

# %%
# Example 1 if-statement: To check if a user is logged in
is_logged_in = True  # Let's define this variable as True for now

if is_logged_in:
    print("Welcome, user!")
else:
    print("Please log in.")

# %%
#@markdown ## Check if a number is even

number = 0  #@param {type: "number"}
if number % 2 == 0:
  print("The number is even!")
else:
  print("The number is odd!")

# %% [markdown]
# ## Repetitions (=*loops*)

# %%
# Example 2: loops: Iterate over a list of numbers
numbers = [1, 2, 3, 4, 5]  # You can change this list to test different cases

for number in numbers:
    print("The current number is:", number)
# Out:
# The current number is: 1
# The current number is: 2
# The current number is: 3
# The current number is: 4
# The current number is: 5

# %%
# Example 2: loops: Iterate over a list of names
names = ["Alice", "Bob", "Charlie"]  # List of names

for name in names:
    print(f"Hello, {name}!")
# Out:
# Hello, Alice!
# Hello, Bob!
# Hello, Charlie!

# %% [markdown]
# ## Functions

# %%
# Example 1: Functions: Add two numbers
def add_numbers(a, b):
    return a + b

# Calling the function and printing the result
result = add_numbers(3, 5)
print(f"The sum of 3 and 5 is: {result}")
# Out:
# The sum of 3 and 5 is: 8

# %% [markdown]
# # Option A: The Math problem 🧮

# %% [markdown]
# ### A1: Using a function to create a distribution and fit a linear regression with matplotlib and scipy

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# Generate 100 random x values
x_values = np.arange(100)

# Generate random perturbations (delta) for each data point
delta = np.random.uniform(-10, 10, size=(100,))

# Create y values using the linear function y = 0.4*x + 3 + delta
def f(x):
    return 0.4 * x + 3 + delta

y_values = f(x_values)

# %%
# Plot the scatterplot
plt.scatter(x_values, y_values, label="Data points", color="blue")

# %%
# Calculate the linear regression
slope, intercept, r_value, p_value, stderr = stats.linregress(x_values, y_values)

# Create the regression line
regression_line = slope * x_values + intercept

# Plot the scatterplot
plt.scatter(x_values, y_values, label="Data points", color="blue")
plt.plot(x_values, regression_line, label="Regression line", color="red")

# Add labels and title
plt.xlabel("X values")
plt.ylabel("Y values")
plt.title("Scatterplot with Linear Regression Line")

# Show the plot
plt.legend()
plt.show()

# %% [markdown]
# ### A2: Fitting and plotting a non-linear distribution with sklearn and seaborn and pandas

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Define the function
def f(x): # we have created a function simlar to our 'school maths' notation; we could have given it any name
    return x**5 # this is the Python notation for 'to the power of 5'

# Generate values for x
x = np.linspace(-2, 2, 50)  # this is not working with continuous values, but with a range of 50 values between -2 and 2

# Compute corresponding y values
y = f(x)

# %% [markdown]
# #### Plotting: Using the Seaborn package
# We can also use another package to make the plot more appealing. We will use seaborn for this.

# %%
# Plot the function using Seaborn
sns.lineplot(x=x, y=y)
# Out:
# <Axes: >

# %% [markdown]
# #### Seaborn: A better workflow
# - we create a Pandas DataFrame
#   - think of this as a (fancy/powerful) spreadsheet in Python
# - we give the columns proper names
# - then we don't have to use workaround for axis title

# %%
import pandas as pd
# Create a DataFrame
A2data = pd.DataFrame({"xSteps": x, "yClean": y})
A2data.head(10)
# Out:
#      xSteps     yClean
# 0 -2.000000 -32.000000
# 1 -1.918367 -25.981180
# 2 -1.836735 -20.904132
# 3 -1.755102 -16.653743
# 4 -1.673469 -13.124684
# 5 -1.591837 -10.220982
# 6 -1.510204  -7.855579
# 7 -1.428571  -5.949902
# 8 -1.346939  -4.433424
# 9 -1.265306  -3.243232

# %%
# Plot the function using Seaborn
sns.lineplot(data=A2data, x="xSteps", y="yClean", legend="full")
# Out:
# <Axes: xlabel='xSteps', ylabel='yClean'>

# %% [markdown]
# #### We generate some spreadsheet data with our noise definition
#
# - we will use a [Gaussian/Normal distribution](https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html) to add some noise to our data
# - while we are at it, we also plot the new data to compare it

# %% [markdown]
# A2.2: Let's create some noisy data and store it as a spreadsheet and a Pandas Dataframe

# %%
# Add Gaussian noise
mean = 0
std_dev = 4  # Adjust the standard deviation to control the noise level
noise = np.random.normal(mean, std_dev, A2data['yClean'].shape)

# Create the noisy y values based on the existing yClean column
A2data['yNoisy'] = A2data['yClean'] + noise

# Display the top 10 lines of the DataFrame
print(A2data.head(10))

# Savining a pandas dataframe to csv
A2data.to_csv('A2data.csv', index=False)
# Out:
#      xSteps     yClean     yNoisy
# 0 -2.000000 -32.000000 -34.773777
# 1 -1.918367 -25.981180 -27.064125
# 2 -1.836735 -20.904132 -24.655365
# 3 -1.755102 -16.653743 -23.081276
# 4 -1.673469 -13.124684 -23.117080
# 5 -1.591837 -10.220982  -6.803103
# 6 -1.510204  -7.855579  -7.043594
# 7 -1.428571  -5.949902  -5.949553
# 8 -1.346939  -4.433424   3.712753
# 9 -1.265306  -3.243232  -2.802372

# %% [markdown]
# #### A2.3: Let's plot the noisy data

# %%
# Plotting
sns.scatterplot(data=A2data, x="xSteps", y="yNoisy", label="Noisy Data", color="red")
plt.title("Adding Gaussian Noise to y = x^5")
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### A2.3 Let's start with the regression (linear and polynomial)
#
# - there are various ways of doing this
# - there are diffferent packages to be used
# - some are better for visualisation
# - some offer detailed statistical analysis
#   - `numpy` is often used, it provides some regression functions, often it is called 'under the hood'
#   - `scipy` is a more advanced package, it offers more statistical analysis
#   - `sklearn` is a machine learning package, it offers a lot of different models, including regression models
#   - `statsmodels` is a package that is often used in academia, it offers a lot of statistical analysis
#
# For this session, we will use `sklearn` as it gives us a good balance between visualisation and statistical analysis

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt


# Extracting features (X) and target variable (y)
X = A2data[['xSteps']]
y = A2data['yNoisy']

# Transforming features to polynomial features of degree 3
poly = PolynomialFeatures(degree=5, include_bias=False)
X_poly = poly.fit_transform(X)

# Fitting the model
model = LinearRegression()
model.fit(X_poly, y)

X_fit_poly = poly.transform(X)
y_fit = model.predict(X_fit_poly)

# plot distribution
sns.scatterplot(data=A2data, x="xSteps", y="yNoisy", label="Distribution", color="green")

# Plotting the polynomial regression curve
plt.plot(X, y_fit, color='red', label='Polynomial Regression Curve')

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Polynomial Regression')
plt.legend()
plt.show()

# Print the coefficients
print("Coefficients:", model.coef_)
# Out:
# Coefficients: [ 0.7796512   2.25582131 -0.71175083 -0.53398937  1.23270571]

# %% [markdown]
# # Option B: The Waiter and the tips

# %% [markdown]
# ### B1: Import data from a respository
# - we will import an Excel file use the `seaborn` package to import the `tips` dataset

# %%
# Define the file name and URL
file_name = "tips.xlsx"
url = "https://github.com/UoA-eResearch/ResBaz24Python/raw/main/Datasets/tips.xlsx"


! wget {url}

# Read the Excel file and load it into a pandas dataframe
tips = pd.read_excel("tips.xlsx", sheet_name="tips")
tips.head()


# use this https://seaborn.pydata.org/tutorial/regression.html
# Out:
# --2024-07-08 05:06:36--  https://github.com/UoA-eResearch/ResBaz24Python/raw/dev/tips.xlsx
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/UoA-eResearch/ResBaz24Python/dev/tips.xlsx [following]
# --2024-07-08 05:06:36--  https://raw.githubusercontent.com/UoA-eResearch/ResBaz24Python/dev/tips.xlsx
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21018 (21K) [application/octet-stream]
# Saving to: ‘tips.xlsx’
#
# tips.xlsx           100%[===================>]  20.53K  --.-KB/s    in 0.002s
#
# 2024-07-08 05:06:36 (11.4 MB/s) - ‘tips.xlsx’ saved [21018/21018]
#    total_bill   tip     sex smoker  day    time  size
# 0        2.00  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### B2: Exploratory Data Analysis (EDA)
#
# - now that we have explored how to import data from an Excel file, make it useable as a Pandas Dataframe and save it back to excel, we will perform some basic EDA
# - we can either
#   - directly look at the data 🔢 🧐
#   - plot it 📈 📊
# - lets try to use only a few lines of code to get an **understanding** of what this 'tips' dataset is
# - for more details see [this EDA example](https://www.kaggle.com/code/mirjanadmitrovic/data-visualization-using-seaborn-tips-dataset)

# %% [markdown]
# ### B2.1 Looking at the data

# %%
# return first 10 rows of the dataframe
tips.head(10) # this time lets show the first 10 rows
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0        2.00  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
# generate general stats for dataframe
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.724508    2.998279    2.569672
# std      8.973226    1.383638    0.951100
# min      2.000000    1.000000    1.000000
# 25%     13.277500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# demonstrate how to return categorical variables for a column in dataframe
tips.sex.unique()

# detect labels in categorical variables
for col in tips.columns[2:6]:
    print(col, np.unique(tips[col]))
# Out:
# sex ['Female' 'Male']
# smoker ['No' 'Yes']
# day ['Fri' 'Sat' 'Sun' 'Thur']
# time ['Dinner' 'Lunch']

# %% [markdown]
# ### B3.2 Plotting the data
# - firstly with just one line of code
# - then with some refined package (Seaborn `sns pairplot`)

# %%
# We can plot data using the plotting function available with Pandas
tips.plot(x='total_bill', y='tip', kind='scatter', title='Total bill vs. Tip')
# Out:
# <Axes: title={'center': 'Total bill vs. Tip'}, xlabel='total_bill', ylabel='tip'>

# %%
# We can create more complex plots passing the dataframe to seaborn plotting functions
sns.pairplot(tips)

# %%
# We can use other functions in seaborn to visualise categorical and numerical data on the same plot. e.g. relplot
sns.relplot(x='total_bill', y='tip', data=tips, hue='size', size='size', style='sex', sizes=(10,200), palette='viridis')

# %% [markdown]
# Let's have a look at the non-number data types
# - Don't worry, this looks like 'a lot' but, in essence, it is a loop over all the categorials (so not numeric data types) and then we plot them

# %%
# Create a figure with subplots
fig, axes = plt.subplots(nrows=len(tips.select_dtypes(include='object').columns), ncols=1, figsize=(8, 4 * len(tips.select_dtypes(include='object').columns)))

# Loop over each categorical column and plot
for ax, column in zip(axes, tips.select_dtypes(include='object').columns):
    tips[column].value_counts().plot(kind='bar', ax=ax)
    value_counts = tips[column].value_counts()
    bars = value_counts.plot(kind='bar', ax=ax)

plt.tight_layout(h_pad=5.0)
plt.show()

# %% [markdown]
# ### B3.3 So? What do we learn about our data?
#
# - over to you

# %% [markdown]
# ## B4: Adding data
#   - B4.1 The waiter kept collecting data; we want to append this data to our existing dataset
#   - B4.2 Another waiter in the same restaurant collected data. But used a different sequence of the columns.
#   - B4.3 In two other restaurants similar data was collected. We want to merge all this data into one dataset.
#
# ### B4.1 append with more data
# - we will append some more data to the `tips` dataframe
# - to clearly identify where the data stems from, we will add a new column to the existing dataframe named 'source'
# - when we (accidentally) re-run this cell, we will keep adding data; this is not what we want. We will fix with *a conditional*.

# %%
# add a new column 'source' to the tips dataframe and set it to 'Day1'
tips['source'] = 'Day1'
# Display the top 10 lines of the dataframe
tips.head(10)

# get file from repo
url = "https://github.com/UoA-eResearch/ResBaz24Python/raw/main/Datasets/tips_dayB.csv"
! wget {url}

# Load the CSV file into a pandas dataframe
tips2 = pd.read_csv('tips_dayB.csv')
tips2['source'] = 'Day2'

# Append the tips2 dataframe to the tips dataframe
tipsB41 = pd.concat([tips, tips2], ignore_index=True)

# Display the top 10 lines of the dataframe
tipsB41.tail(10)

tipsB41.shape
# Out:
# --2024-07-08 05:07:20--  https://github.com/UoA-eResearch/ResBaz24Python/raw/dev2/B4.1tips.csv
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/UoA-eResearch/ResBaz24Python/dev2/B4.1tips.csv [following]
# --2024-07-08 05:07:21--  https://raw.githubusercontent.com/UoA-eResearch/ResBaz24Python/dev2/B4.1tips.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29698 (29K) [text/plain]
# Saving to: ‘B4.1tips.csv’
#
# B4.1tips.csv        100%[===================>]  29.00K  --.-KB/s    in 0.004s
#
# 2024-07-08 05:07:21 (6.67 MB/s) - ‘B4.1tips.csv’ saved [29698/29698]
# (744, 8)

# %% [markdown]
# Let's see if there are duplicates in the data

# %%
# Find duplicated rows
duplicated_rows = tipsB41[tipsB41.duplicated(keep=False)]

print(duplicated_rows)
# Out:
#      total_bill  tip     sex smoker   day   time  size source
# 198        13.0  2.0  Female    Yes  Thur  Lunch     2   Day1
# 202        13.0  2.0  Female    Yes  Thur  Lunch     2   Day1

# %% [markdown]
# there is just one duplicated line, that should be fine

# %% [markdown]
# ### B4.2 Another waiter in the same restaurant collected data but with differen column sequence
# - we import a dataset from another waiter
#   - but this person had a different column sequence
# - we will try to merge these two datasets
# - then we will try to get an impression of how they differ

# %%
url = "https://github.com/UoA-eResearch/ResBaz24Python/raw/main/Datasets/tips_waiterB.csv"
! wget {url}

# import the data
tipsB42 = pd.read_csv('tips_waiterB.csv')
tipsB42['waiter'] = 'WaiterB'
tipsB41['waiter'] = 'WaiterA'
tipsB42_together = pd.concat([tipsB41, tipsB42], ignore_index=True)
tipsB42_together.tail(10)
# Out:
# --2024-07-08 05:07:30--  https://github.com/UoA-eResearch/ResBaz24Python/raw/dev2/B4.2tips.csv
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/UoA-eResearch/ResBaz24Python/dev2/B4.2tips.csv [following]
# --2024-07-08 05:07:30--  https://raw.githubusercontent.com/UoA-eResearch/ResBaz24Python/dev2/B4.2tips.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23607 (23K) [text/plain]
# Saving to: ‘B4.2tips.csv’
#
# B4.2tips.csv        100%[===================>]  23.05K  --.-KB/s    in 0.002s
#
# 2024-07-08 05:07:30 (11.9 MB/s) - ‘B4.2tips.csv’ saved [23607/23607]
#       total_bill       tip     sex smoker   day    time  size source   waiter
# 1134   22.488395  5.458388  Female     No   Fri  Dinner     2    NaN  WaiterB
# 1135   25.471567  1.911591    Male     No   Fri   Lunch     2    NaN  WaiterB
# 1136   14.210704  2.937472    Male    Yes  Thur   Lunch     4    NaN  WaiterB
# 1137    4.485845  7.209639  Female     No   Sat  Dinner     2    NaN  WaiterB
# 1138   27.942513  6.258671    Male    Yes  Thur  Dinner     1    NaN  WaiterB
# 1139   24.071770  6.019978  Female     No   Fri   Lunch     4    NaN  WaiterB
# 1140   16.784624  5.990757  Female    Yes   Sat   Lunch     3    NaN  WaiterB
# 1141   19.242330  4.708516    Male    Yes  Thur   Lunch     4    NaN  WaiterB
# 1142   17.835907  4.230224  Female    Yes  Thur   Lunch     3    NaN  WaiterB
# 1143   16.392372  4.998314  Female    Yes   Sat   Lunch     1    NaN  WaiterB

# %% [markdown]
# Poll
# - what should we do now?
# - look at the values?
# - look at some plots?

# %%
# How could we look at the variety of distributions for both waiters?
sns.pairplot(tipsB42_together, hue='waiter')

# %%
url = "https://github.com/UoA-eResearch/ResBaz24Python/raw/main/Datasets/tips_restaurantB.csv"
! wget {url}

# import the data
tipsB43 = pd.read_csv('tips_restaurantB.csv')
tipsB42_together['restaurant'] = 'RestaurantX'
tipsB43['restaurant'] = 'RestaurantY'
tipsB43_together = pd.concat([tipsB42_together, tipsB43], ignore_index=True)
tipsB43_together.tail(10)
# Out:
#       total_bill       tip     sex smoker   day    time  size source waiter  \
# 1834   33.419100  4.911257  Female    Yes   Sun   Lunch     2    NaN    NaN
# 1835   47.533096  7.951311  Female    Yes   Fri   Lunch     4    NaN    NaN
# 1836   44.013965  4.592673  Female     No  Thur  Dinner     3    NaN    NaN
# 1837   44.022460  5.195435    Male    Yes   Sun   Lunch     3    NaN    NaN
# 1838   48.948620  1.704194  Female    Yes  Thur   Lunch     5    NaN    NaN
# 1839   20.098824  2.344669  Female    Yes  Thur  Dinner     2    NaN    NaN
# 1840   41.821367  6.859331  Female    Yes   Fri   Lunch     3    NaN    NaN
# 1841   44.348958  7.380565    Male     No  Thur   Lunch     5    NaN    NaN
# 1842   34.433683  4.139908  Female    Yes   Fri  Dinner     2    NaN    NaN
# 1843   33.492969  4.436787  Female    Yes   Fri   Lunch     2    NaN    NaN
#
#        restaurant
# 1834  RestaurantY
# 1835  RestaurantY
# 1836  RestaurantY
# 1837  RestaurantY
# 1838  RestaurantY
# 1839  RestaurantY
# 1840  RestaurantY
# 1841  RestaurantY
# 1842  RestaurantY
# 1843  RestaurantY

# %%
sns.pairplot(tipsB43_together, hue='restaurant')

# %% [markdown]
# # Revisiting the Goals

# %% [markdown]
# Did you?
#   - ... have fun! 🎉
#   - ... follow along while live coding in Python 🐍
#   - ... pick up some core coding concepts while doing that?
#   - ... make a decision if Python is something you want to learn/use? If so:
#       - Carp
#       - ML
#       - hand-selected links below
#
#   Now that we have this experience in Google Colab, which is one flavour of a Jupyter Notebook
#   - University of Auckland researchers have access to the [Nectar Research Cloud](https://research-hub.auckland.ac.nz/research-software-and-computing/advanced-compute/nectar-research-cloud) and sevices like [JupyterHub](https://research-hub.auckland.ac.nz/research-software-and-computing/advanced-compute/nectar-jupyterhub), [BinderHub](https://research-hub.auckland.ac.nz/research-software-and-computing/advanced-compute/nectar-binderhub), and [Nectar Virtual Desktop](https://research-hub.auckland.ac.nz/research-software-and-computing/advanced-compute/nectar-virtual-desktop)
#   - if you automate tasks, make machines talk to other machines, etc. you can write scripts and run them on the command-line
#   - you can use an Integrated Development Environment (IDE) like [Visual Studio Code](https://code.visualstudio.com/) or [PyCharm](https://www.jetbrains.com/pycharm/)
#
# Were your goals met? 🎯

# %% [markdown]
# # Resources

# %% [markdown]
# ## Websites for Learning Python:
#
# -   [HarvardX: Using Python for Research](https://www.edx.org/learn/python/harvard-university-using-python-for-research)
# -   [LearnPython.org](https://www.learnpython.org/) This is a free interactive Python tutorial for people who want to learn Python
# -   [Google\'s Python Class](https://developers.google.com/edu/python)
#     Google also has an excellent set of Python tutorials for beginners
# -   [Codecademy](https://www.codecademy.com/) offers an interactive
#     Python course
# -   [30 Days of Python](https://github.com/Asabeneh/30-Days-Of-Python)
# -   [How to Think Like a Computer Scientist](https://runestone.academy/runestone/books/published/thinkcspy/index.html)
#
# ## Video for Learning Python
#
# -   [freeCodeCamp.org](https://youtu.be/rfscVS0vtbw?si=EiY8F-GupxBrtovb)
#
# ## Python Blogs:
#
# -   [Real Python](http://ttps://realpython.com/) is a comprehensive
#     Python programming blog with eye-catching infographics, videos, and
#     an overall fun vibe
# -   [Planet Python](https://planetpython.org/) is a comprehensive blog
#     that brings together recent Python-related posts from various other
#     blogs
# -   [Finxter](https://blog.finxter.com/) is another Python blog to
#     follow
# -   [Full Stack Python](https://www.fullstackpython.com/) is a blog that
#     provides detailed tutorials on various platforms utilizing Python
#
# ## Python Games
# - [CodeCombat](https://codecombat.com/): Learn programming through an interactive game-based platform where players write code to control characters and solve challenges.
# - [Code on the Cob](https://www.codeonthecob.com/): A webiste to practice coding
# - [CheckiO](https://checkio.org/): Learn Python coding through solving coding challenges in a gamified environment, with a focus on improving coding skills.
# - [Advent of Code](https://adventofcode.com/): An annual coding challenge held in December, featuring daily programming puzzles to solve.
# - [CodinGame](https://www.codingame.com/start/): Learn coding through gamified programming puzzles and challenges, covering various languages and difficulty levels.
# - [LeetCode](https://leetcode.com/): Practice coding skills through a collection of coding problems, ranging from easy to hard, often used for technical interviews.
# - [Exercism](https://exercism.org/tracks/python): Learn programming languages through practice problems with mentors, focusing on feedback-driven learning and community support.
